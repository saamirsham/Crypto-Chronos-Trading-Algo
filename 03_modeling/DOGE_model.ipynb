# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('../data/ready/DOGE.csv',index_col='time').drop('Unnamed: 0', axis = 1).dropna()
df.shape
# Out:
# (60, 20)

# %%
df['met_threshold'].value_counts(normalize=True)
# Out:
# 1.0    0.866667
# 0.0    0.133333
# Name: met_threshold, dtype: float64

# %%
target = df['met_threshold']
features = df.drop(['met_threshold','lag_time'], axis=1)
scaler = StandardScaler()
features = scaler.fit_transform(features)
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
met_threshold_model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(features_train.shape[1],)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

met_threshold_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = met_threshold_model.fit(features_train, target_train, epochs=50, validation_data=(features_test, target_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 100ms/step - loss: 0.6099 - accuracy: 0.7500 - val_loss: 0.4986 - val_accuracy: 1.0000
# Epoch 2/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5830 - accuracy: 0.8125 - val_loss: 0.4538 - val_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5115 - accuracy: 0.8333 - val_loss: 0.4146 - val_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5140 - accuracy: 0.8333 - val_loss: 0.3819 - val_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4615 - accuracy: 0.8333 - val_loss: 0.3526 - val_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4536 - accuracy: 0.8333 - val_loss: 0.3267 - val_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4565 - accuracy: 0.8333 - val_loss: 0.3040 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4359 - accuracy: 0.8333 - val_loss: 0.2851 - val_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4461 - accuracy: 0.8333 - val_loss: 0.2678 - val_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3916 - accuracy: 0.8333 - val_loss: 0.2517 - val_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3839 - accuracy: 0.8333 - val_loss: 0.2393 - val_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3797 - accuracy: 0.8333 - val_loss: 0.2280 - val_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3583 - accuracy: 0.8333 - val_loss: 0.2174 - val_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3376 - accuracy: 0.8333 - val_loss: 0.2089 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3547 - accuracy: 0.8333 - val_loss: 0.2007 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3345 - accuracy: 0.8333 - val_loss: 0.1930 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3199 - accuracy: 0.8333 - val_loss: 0.1866 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3201 - accuracy: 0.8333 - val_loss: 0.1808 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3323 - accuracy: 0.8333 - val_loss: 0.1751 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2993 - accuracy: 0.8333 - val_loss: 0.1695 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2978 - accuracy: 0.8333 - val_loss: 0.1634 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2747 - accuracy: 0.8542 - val_loss: 0.1593 - val_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2877 - accuracy: 0.8333 - val_loss: 0.1557 - val_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2581 - accuracy: 0.8750 - val_loss: 0.1529 - val_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2547 - accuracy: 0.8542 - val_loss: 0.1496 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2889 - accuracy: 0.8333 - val_loss: 0.1463 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2381 - accuracy: 0.8750 - val_loss: 0.1442 - val_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2323 - accuracy: 0.8958 - val_loss: 0.1422 - val_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2225 - accuracy: 0.8958 - val_loss: 0.1396 - val_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2411 - accuracy: 0.8542 - val_loss: 0.1377 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2129 - accuracy: 0.8750 - val_loss: 0.1350 - val_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2191 - accuracy: 0.8750 - val_loss: 0.1323 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2265 - accuracy: 0.8958 - val_loss: 0.1296 - val_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2215 - accuracy: 0.8958 - val_loss: 0.1279 - val_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2131 - accuracy: 0.9167 - val_loss: 0.1260 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2175 - accuracy: 0.8958 - val_loss: 0.1241 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2082 - accuracy: 0.8750 - val_loss: 0.1218 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2027 - accuracy: 0.9167 - val_loss: 0.1187 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1951 - accuracy: 0.9167 - val_loss: 0.1151 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2104 - accuracy: 0.9375 - val_loss: 0.1120 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2101 - accuracy: 0.8958 - val_loss: 0.1088 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1999 - accuracy: 0.9167 - val_loss: 0.1065 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1931 - accuracy: 0.9375 - val_loss: 0.1050 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1740 - accuracy: 0.9167 - val_loss: 0.1037 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1973 - accuracy: 0.9167 - val_loss: 0.1023 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1772 - accuracy: 0.9375 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1837 - accuracy: 0.9583 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1683 - accuracy: 0.9375 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1622 - accuracy: 0.9375 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1706 - accuracy: 0.9167 - val_loss: 0.0921 - val_accuracy: 1.0000

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %%
predictions = met_threshold_model.predict(features)
predicted_classes = (predictions >0.5).astype('int32')
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
accuracy = accuracy_score(target, predicted_classes)
print(f"Accuracy: {accuracy * 100}%")

cm = confusion_matrix(target, predicted_classes)

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix')
plt.show()
# Out:
# Accuracy: 98.33333333333333%

# %%
df_predicted = df.copy()
df_predicted['met_threshold'] = predicted_classes
df_predicted['lag_time'] = pd.to_timedelta(df['lag_time']).dt.total_seconds() / 3600

# %%
features = df_predicted.drop('lag_time', axis=1)
target = df_predicted['lag_time']

features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

scaler = StandardScaler()
features_train = scaler.fit_transform(features_train)
features_test = scaler.transform(features_test)

# %%
lag_model = Sequential([
    Dense(64, activation='relu', input_shape=(features_train.shape[1],), kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(1)
])

lag_model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = lag_model.fit(features_train, target_train, 
                    epochs=200, 
                    validation_data=(features_test, target_test),
                    callbacks=[early_stop])
# Out:
# Epoch 1/200
# 2/2 [==============================] - 0s 87ms/step - loss: 7.9248 - val_loss: 9.8600
# Epoch 2/200
# 2/2 [==============================] - 0s 21ms/step - loss: 7.0410 - val_loss: 8.9457
# Epoch 3/200
# 2/2 [==============================] - 0s 21ms/step - loss: 7.2261 - val_loss: 8.1533
# Epoch 4/200
# 2/2 [==============================] - 0s 21ms/step - loss: 6.0994 - val_loss: 7.4353
# Epoch 5/200
# 2/2 [==============================] - 0s 21ms/step - loss: 5.3284 - val_loss: 6.7742
# Epoch 6/200
# 2/2 [==============================] - 0s 20ms/step - loss: 4.7114 - val_loss: 6.1592
# Epoch 7/200
# 2/2 [==============================] - 0s 20ms/step - loss: 5.2147 - val_loss: 5.6095
# Epoch 8/200
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9301 - val_loss: 5.1362
# Epoch 9/200
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4666 - val_loss: 4.6981
# Epoch 10/200
# 2/2 [==============================] - 0s 21ms/step - loss: 3.9128 - val_loss: 4.3061
# Epoch 11/200
# 2/2 [==============================] - 0s 25ms/step - loss: 3.3207 - val_loss: 3.9494
# Epoch 12/200
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1953 - val_loss: 3.6266
# Epoch 13/200
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4040 - val_loss: 3.3644
# Epoch 14/200
# 2/2 [==============================] - 0s 23ms/step - loss: 3.0622 - val_loss: 3.1375
# Epoch 15/200
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8008 - val_loss: 2.9402
# Epoch 16/200
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0497 - val_loss: 2.7677
# Epoch 17/200
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7462 - val_loss: 2.6380
# Epoch 18/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.5362 - val_loss: 2.5428
# Epoch 19/200
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3170 - val_loss: 2.4685
# Epoch 20/200
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6932 - val_loss: 2.4236
# Epoch 21/200
# 2/2 [==============================] - 0s 23ms/step - loss: 2.5407 - val_loss: 2.3903
# Epoch 22/200
# 2/2 [==============================] - 0s 37ms/step - loss: 2.7900 - val_loss: 2.3767
# Epoch 23/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.5414 - val_loss: 2.3707
# Epoch 24/200
# 2/2 [==============================] - 0s 24ms/step - loss: 1.7286 - val_loss: 2.3579
# Epoch 25/200
# 2/2 [==============================] - 0s 24ms/step - loss: 2.1019 - val_loss: 2.3313
# Epoch 26/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8381 - val_loss: 2.3018
# Epoch 27/200
# 2/2 [==============================] - 0s 24ms/step - loss: 2.0469 - val_loss: 2.2617
# Epoch 28/200
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0441 - val_loss: 2.2283
# Epoch 29/200
# 2/2 [==============================] - 0s 24ms/step - loss: 2.2323 - val_loss: 2.1874
# Epoch 30/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1610 - val_loss: 2.1563
# Epoch 31/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.9525 - val_loss: 2.1228
# Epoch 32/200
# 2/2 [==============================] - 0s 23ms/step - loss: 2.2577 - val_loss: 2.0903
# Epoch 33/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.9752 - val_loss: 2.0601
# Epoch 34/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8775 - val_loss: 2.0443
# Epoch 35/200
# 2/2 [==============================] - 0s 23ms/step - loss: 2.1300 - val_loss: 2.0249
# Epoch 36/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6787 - val_loss: 2.0095
# Epoch 37/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0990 - val_loss: 1.9864
# Epoch 38/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6673 - val_loss: 1.9628
# Epoch 39/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1917 - val_loss: 1.9459
# Epoch 40/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.5305 - val_loss: 1.9295
# Epoch 41/200
# 2/2 [==============================] - 0s 24ms/step - loss: 1.9576 - val_loss: 1.9091
# Epoch 42/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7410 - val_loss: 1.8875
# Epoch 43/200
# 2/2 [==============================] - 0s 24ms/step - loss: 2.1196 - val_loss: 1.8747
# Epoch 44/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7110 - val_loss: 1.8802
# Epoch 45/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8889 - val_loss: 1.8874
# Epoch 46/200
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0702 - val_loss: 1.8964
# Epoch 47/200
# 2/2 [==============================] - 0s 23ms/step - loss: 2.1710 - val_loss: 1.9020
# Epoch 48/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4862 - val_loss: 1.9069
# Epoch 49/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5642 - val_loss: 1.9051
# Epoch 50/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7835 - val_loss: 1.8964
# Epoch 51/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5842 - val_loss: 1.8767
# Epoch 52/200
# 2/2 [==============================] - 0s 26ms/step - loss: 1.7427 - val_loss: 1.8527
# Epoch 53/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8468 - val_loss: 1.8290
# Epoch 54/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4938 - val_loss: 1.8309
# Epoch 55/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.3922 - val_loss: 1.8426
# Epoch 56/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5244 - val_loss: 1.8475
# Epoch 57/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5840 - val_loss: 1.8515
# Epoch 58/200
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5376 - val_loss: 1.8501
# Epoch 59/200
# 2/2 [==============================] - 0s 24ms/step - loss: 1.3684 - val_loss: 1.8462
# Epoch 60/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4967 - val_loss: 1.8386
# Epoch 61/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6343 - val_loss: 1.8454
# Epoch 62/200
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4979 - val_loss: 1.8459
# Epoch 63/200
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6545 - val_loss: 1.8386

# %%
# Make predictions on the test set
predictions_test = lag_model.predict(features_test)

# Create a scatter plot of the actual versus predicted values
plt.figure(figsize=(8, 8))
plt.scatter(target_test, predictions_test, alpha=0.2)
plt.plot([target_test.min(), target_test.max()], [target_test.min(), target_test.max()], 'k--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
plt.show()

# Create a plot of the training and validation loss
plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %%
features_scaled = scaler.transform(features)
predictions_all = lag_model.predict(features_scaled)
df_predicted['lag_time'] = np.around(predictions_all).flatten()
df_predicted.head()
# Out:
# 2/2 [==============================] - 0s 2ms/step
#                      BTC_open  BTC_close    BTC_volume  DOGE_open  DOGE_close  \
# time
# 2017-01-07 10:00:00    824.16     867.68  8.454079e+06   0.000220    0.000217
# 2017-03-10 13:00:00   1199.95    1268.92  3.985328e+07   0.000204    0.000216
# 2017-06-15 14:00:00   2152.75    2273.54  4.840666e+07   0.002704    0.002655
# 2017-07-20 11:00:00   2354.80    2472.97  4.957016e+07   0.001676    0.001869
# 2017-09-15 12:00:00   3018.12    3360.86  1.559127e+08   0.000694    0.000709
#
#                      DOGE_volume  perc_BTC_change_1hr  perc_BTC_change_2hr  \
# time
# 2017-01-07 10:00:00        11.72             5.280528             5.444293
# 2017-03-10 13:00:00     12399.18             5.747739             5.987989
# 2017-06-15 14:00:00       522.63             5.610963            -1.826127
# 2017-07-20 11:00:00       199.89             5.018261             5.497182
# 2017-09-15 12:00:00      1007.97            11.356076            10.808663
#
#                      perc_BTC_change_3hr  perc_BTC_change_4hr  \
# time
# 2017-01-07 10:00:00             7.106442             4.150762
# 2017-03-10 13:00:00             5.856247             6.474458
# 2017-06-15 14:00:00            -1.622646            -3.270905
# 2017-07-20 11:00:00             5.382095             5.783289
# 2017-09-15 12:00:00             9.886610             6.705147
#
#                      perc_BTC_change_5hr  perc_BTC_change_6hr  \
# time
# 2017-01-07 10:00:00             3.461516             5.348275
# 2017-03-10 13:00:00             6.916745             6.738671
# 2017-06-15 14:00:00            -5.560748            -7.978062
# 2017-07-20 11:00:00             5.560227             4.625050
# 2017-09-15 12:00:00             7.347253             7.185319
#
#                      perc_DOGE_change_1hr  perc_DOGE_change_2hr  \
# time
# 2017-01-07 10:00:00              1.073262             -1.545455
# 2017-03-10 13:00:00              2.082347              2.034059
# 2017-06-15 14:00:00             -1.812130             -3.172867
# 2017-07-20 11:00:00             11.515513              8.852650
# 2017-09-15 12:00:00              2.161383            -19.623625
#
#                      perc_DOGE_change_3hr  perc_DOGE_change_4hr  \
# time
# 2017-01-07 10:00:00             -0.960219             -3.818828
# 2017-03-10 13:00:00              3.205742              4.404647
# 2017-06-15 14:00:00             -2.425579             -6.084188
# 2017-07-20 11:00:00              9.298246              9.747504
# 2017-09-15 12:00:00            -19.641845            -19.614512
#
#                      perc_DOGE_change_5hr  perc_DOGE_change_6hr  lag_time  \
# time
# 2017-01-07 10:00:00            -13.360000            -41.930295       6.0
# 2017-03-10 13:00:00              2.130682              4.404647       2.0
# 2017-06-15 14:00:00             -4.393230             -6.842105       6.0
# 2017-07-20 11:00:00             10.657194             13.547995       3.0
# 2017-09-15 12:00:00            -19.523269            -25.391981       4.0
#
#                      met_threshold
# time
# 2017-01-07 10:00:00              1
# 2017-03-10 13:00:00              1
# 2017-06-15 14:00:00              1
# 2017-07-20 11:00:00              1
# 2017-09-15 12:00:00              1

# %%
df_predicted.to_csv('../data/predictions/DOGE_predicted.csv')
