# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('../data/ready/LTC.csv',index_col='time').drop('Unnamed: 0', axis = 1).dropna()
df.shape
# Out:
# (60, 20)

# %%
df['met_threshold'].value_counts(normalize=True)
# Out:
# 1.0    0.9
# 0.0    0.1
# Name: met_threshold, dtype: float64

# %%
target = df['met_threshold']
features = df.drop(['met_threshold','lag_time'], axis=1)
scaler = StandardScaler()
features = scaler.fit_transform(features)
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
met_threshold_model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(features_train.shape[1],)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

met_threshold_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = met_threshold_model.fit(features_train, target_train, epochs=20, validation_data=(features_test, target_test))
# Out:
# Epoch 1/20
# 2/2 [==============================] - 1s 213ms/step - loss: 0.6760 - accuracy: 0.5208 - val_loss: 0.5191 - val_accuracy: 0.9167
# Epoch 2/20
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5947 - accuracy: 0.6250 - val_loss: 0.4689 - val_accuracy: 0.9167
# Epoch 3/20
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5394 - accuracy: 0.8333 - val_loss: 0.4255 - val_accuracy: 1.0000
# Epoch 4/20
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5176 - accuracy: 0.7917 - val_loss: 0.3890 - val_accuracy: 1.0000
# Epoch 5/20
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4429 - accuracy: 0.9375 - val_loss: 0.3573 - val_accuracy: 1.0000
# Epoch 6/20
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4724 - accuracy: 0.8542 - val_loss: 0.3304 - val_accuracy: 0.9167
# Epoch 7/20
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4106 - accuracy: 0.8750 - val_loss: 0.3073 - val_accuracy: 0.9167
# Epoch 8/20
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3740 - accuracy: 0.8958 - val_loss: 0.2886 - val_accuracy: 0.9167
# Epoch 9/20
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3437 - accuracy: 0.9167 - val_loss: 0.2725 - val_accuracy: 0.9167
# Epoch 10/20
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3600 - accuracy: 0.8958 - val_loss: 0.2595 - val_accuracy: 0.9167
# Epoch 11/20
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3325 - accuracy: 0.8958 - val_loss: 0.2494 - val_accuracy: 0.9167
# Epoch 12/20
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2882 - accuracy: 0.9167 - val_loss: 0.2409 - val_accuracy: 0.9167
# Epoch 13/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3009 - accuracy: 0.8958 - val_loss: 0.2339 - val_accuracy: 0.9167
# Epoch 14/20
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3130 - accuracy: 0.8958 - val_loss: 0.2286 - val_accuracy: 0.9167
# Epoch 15/20
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3097 - accuracy: 0.8958 - val_loss: 0.2247 - val_accuracy: 0.9167
# Epoch 16/20
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2699 - accuracy: 0.8958 - val_loss: 0.2220 - val_accuracy: 0.9167
# Epoch 17/20
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2649 - accuracy: 0.8958 - val_loss: 0.2199 - val_accuracy: 0.9167
# Epoch 18/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2725 - accuracy: 0.8958 - val_loss: 0.2186 - val_accuracy: 0.9167
# Epoch 19/20
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2715 - accuracy: 0.8958 - val_loss: 0.2180 - val_accuracy: 0.9167
# Epoch 20/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2607 - accuracy: 0.8958 - val_loss: 0.2177 - val_accuracy: 0.9167

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %%
predictions = met_threshold_model.predict(features)
predicted_classes = (predictions >0.5).astype('int32')
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
accuracy = accuracy_score(target, predicted_classes)
print(f"Accuracy: {accuracy * 100}%")

cm = confusion_matrix(target, predicted_classes)

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix')
plt.show()
# Out:
# Accuracy: 90.0%

# %%
df_predicted = df.copy()
df_predicted['met_threshold'] = predicted_classes
df_predicted['lag_time'] = pd.to_timedelta(df['lag_time']).dt.total_seconds() / 3600

# %%
features = df_predicted.drop('lag_time', axis=1)
target = df_predicted['lag_time']

features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

scaler = StandardScaler()
features_train = scaler.fit_transform(features_train)
features_test = scaler.transform(features_test)

# %%
lag_model = Sequential([
    Dense(64, activation='relu', input_shape=(features_train.shape[1],), kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(1)
])

lag_model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = lag_model.fit(features_train, target_train, 
                    epochs=100, 
                    validation_data=(features_test, target_test),
                    callbacks=[early_stop])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 105ms/step - loss: 6.9306 - val_loss: 6.2703
# Epoch 2/100
# 2/2 [==============================] - 0s 24ms/step - loss: 5.2178 - val_loss: 5.6689
# Epoch 3/100
# 2/2 [==============================] - 0s 22ms/step - loss: 5.0979 - val_loss: 5.1869
# Epoch 4/100
# 2/2 [==============================] - 0s 23ms/step - loss: 4.6106 - val_loss: 4.8014
# Epoch 5/100
# 2/2 [==============================] - 0s 24ms/step - loss: 4.2839 - val_loss: 4.4517
# Epoch 6/100
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9300 - val_loss: 4.1469
# Epoch 7/100
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0572 - val_loss: 3.8853
# Epoch 8/100
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1698 - val_loss: 3.6986
# Epoch 9/100
# 2/2 [==============================] - 0s 21ms/step - loss: 3.2015 - val_loss: 3.5640
# Epoch 10/100
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0488 - val_loss: 3.4512
# Epoch 11/100
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1868 - val_loss: 3.3627
# Epoch 12/100
# 2/2 [==============================] - 0s 21ms/step - loss: 3.0001 - val_loss: 3.2964
# Epoch 13/100
# 2/2 [==============================] - 0s 21ms/step - loss: 3.2762 - val_loss: 3.2401
# Epoch 14/100
# 2/2 [==============================] - 0s 21ms/step - loss: 3.6398 - val_loss: 3.1700
# Epoch 15/100
# 2/2 [==============================] - 0s 23ms/step - loss: 2.9157 - val_loss: 3.1158
# Epoch 16/100
# 2/2 [==============================] - 0s 22ms/step - loss: 2.9140 - val_loss: 3.0438
# Epoch 17/100
# 2/2 [==============================] - 0s 22ms/step - loss: 2.7955 - val_loss: 2.9739
# Epoch 18/100
# 2/2 [==============================] - 0s 27ms/step - loss: 3.0174 - val_loss: 2.9220
# Epoch 19/100
# 2/2 [==============================] - 0s 25ms/step - loss: 2.8865 - val_loss: 2.8774
# Epoch 20/100
# 2/2 [==============================] - 0s 22ms/step - loss: 2.9219 - val_loss: 2.8385
# Epoch 21/100
# 2/2 [==============================] - 0s 22ms/step - loss: 2.2829 - val_loss: 2.8132
# Epoch 22/100
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2347 - val_loss: 2.8076
# Epoch 23/100
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4217 - val_loss: 2.7956
# Epoch 24/100
# 2/2 [==============================] - 0s 24ms/step - loss: 2.2997 - val_loss: 2.7829
# Epoch 25/100
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7358 - val_loss: 2.7821
# Epoch 26/100
# 2/2 [==============================] - 0s 24ms/step - loss: 2.5316 - val_loss: 2.7896
# Epoch 27/100
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4835 - val_loss: 2.7965
# Epoch 28/100
# 2/2 [==============================] - 0s 20ms/step - loss: 3.0103 - val_loss: 2.8233
# Epoch 29/100
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4637 - val_loss: 2.8535
# Epoch 30/100
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5718 - val_loss: 2.8839
# Epoch 31/100
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6075 - val_loss: 2.9084
# Epoch 32/100
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5862 - val_loss: 2.9352
# Epoch 33/100
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2725 - val_loss: 2.9633
# Epoch 34/100
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2887 - val_loss: 2.9793
# Epoch 35/100
# 2/2 [==============================] - 0s 27ms/step - loss: 2.1659 - val_loss: 2.9854

# %%
# Make predictions on the test set
predictions_test = lag_model.predict(features_test)

# Create a scatter plot of the actual versus predicted values
plt.figure(figsize=(8, 8))
plt.scatter(target_test, predictions_test, alpha=0.2)
plt.plot([target_test.min(), target_test.max()], [target_test.min(), target_test.max()], 'k--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
plt.show()

# Create a plot of the training and validation loss
plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
features_scaled = scaler.transform(features)
predictions_all = lag_model.predict(features_scaled)
df_predicted['lag_time'] = np.around(predictions_all).flatten()
df_predicted.head()
# Out:
# 2/2 [==============================] - 0s 2ms/step
#                      BTC_open  BTC_close    BTC_volume  LTC_open  LTC_close  \
# time
# 2017-01-07 10:00:00    824.16     867.68  8.454079e+06     3.494      3.658
# 2017-03-10 13:00:00   1199.95    1268.92  3.985328e+07     3.884      3.908
# 2017-06-15 14:00:00   2152.75    2273.54  4.840666e+07    25.770     26.970
# 2017-07-20 11:00:00   2354.80    2472.97  4.957016e+07    41.450     42.770
# 2017-09-15 12:00:00   3018.12    3360.86  1.559127e+08    37.000     44.990
#
#                       LTC_volume  perc_BTC_change_1hr  perc_BTC_change_2hr  \
# time
# 2017-01-07 10:00:00     61302.42             5.280528             5.444293
# 2017-03-10 13:00:00    210740.66             5.747739             5.987989
# 2017-06-15 14:00:00   2765148.87             5.610963            -1.826127
# 2017-07-20 11:00:00   3147078.88             5.018261             5.497182
# 2017-09-15 12:00:00  33790247.73            11.356076            10.808663
#
#                      perc_BTC_change_3hr  perc_BTC_change_4hr  \
# time
# 2017-01-07 10:00:00             7.106442             4.150762
# 2017-03-10 13:00:00             5.856247             6.474458
# 2017-06-15 14:00:00            -1.622646            -3.270905
# 2017-07-20 11:00:00             5.382095             5.783289
# 2017-09-15 12:00:00             9.886610             6.705147
#
#                      perc_BTC_change_5hr  perc_BTC_change_6hr  \
# time
# 2017-01-07 10:00:00             3.461516             5.348275
# 2017-03-10 13:00:00             6.916745             6.738671
# 2017-06-15 14:00:00            -5.560748            -7.978062
# 2017-07-20 11:00:00             5.560227             4.625050
# 2017-09-15 12:00:00             7.347253             7.185319
#
#                      perc_LTC_change_1hr  perc_LTC_change_2hr  \
# time
# 2017-01-07 10:00:00             4.693761             1.526506
# 2017-03-10 13:00:00             0.025595             0.592021
# 2017-06-15 14:00:00             4.656577            -0.553097
# 2017-07-20 11:00:00             3.184560             4.725759
# 2017-09-15 12:00:00            21.594595            20.875873
#
#                      perc_LTC_change_3hr  perc_LTC_change_4hr  \
# time
# 2017-01-07 10:00:00             3.655426             2.235886
# 2017-03-10 13:00:00             0.514403             0.256542
# 2017-06-15 14:00:00            -0.037064            -1.748634
# 2017-07-20 11:00:00             3.760311             3.709990
# 2017-09-15 12:00:00            10.676507             2.436248
#
#                      perc_LTC_change_5hr  perc_LTC_change_6hr  lag_time  \
# time
# 2017-01-07 10:00:00             1.133536             0.743597       2.0
# 2017-03-10 13:00:00             0.617920             1.322271       2.0
# 2017-06-15 14:00:00            -3.055356            -5.863874       4.0
# 2017-07-20 11:00:00             2.763095             2.149510       2.0
# 2017-09-15 12:00:00             2.975509             3.022670       3.0
#
#                      met_threshold
# time
# 2017-01-07 10:00:00              1
# 2017-03-10 13:00:00              1
# 2017-06-15 14:00:00              1
# 2017-07-20 11:00:00              1
# 2017-09-15 12:00:00              1

# %%
df_predicted.to_csv('../data/predictions/LTC_predicted.csv')
